# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
tips=sns.load_dataset("tips")

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.displot(tips["total_bill"])
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#distribution plot

# %%
#

# %%
sns.barplot(data=tips,x ="sex", y="total_bill", estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x="sex", data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
##box plot
sns.boxplot(x="day", y="total_bill", data=tips,hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#violin plot
sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", split=True, palette="Set1")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#stripplot
sns.stripplot(x="day",y="total_bill", data=tips, jitter =True, palette="deep", hue= "smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#sns.set_theme(style="whitegrid")
#sns.set_theme(style="")

# %%
#swamplot
sns.swarmplot(x="day",y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day",y="total_bill", data=tips, color="black")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(y="day", x="total_bill", data=tips, color="green")
sns.swarmplot(y="day",x="total_bill", data=tips, color="black")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
#factorplot
sns.catplot(x="day", y="total_bill", data=tips, kind="bar")
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Regression plots

# %%
sns.lmplot(x="total_bill", y="tip", data=tips,hue="sex", scatter_kws={"s":100},markers=["o","v"])
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(x="total_bill", y="tip", data=tips,col="sex", row="smoker")
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(x="total_bill", y="tip", data=tips,hue="sex", col= "day", aspect=0.5)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#MAtrix plots
#import another data set
flights= sns.load_dataset("flights")

# %%
flights.head(10)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# 5  1949   Jun         135
# 6  1949   Jul         148
# 7  1949   Aug         148
# 8  1949   Sep         136
# 9  1949   Oct         119

# %%
fc=flights.pivot(index="month", columns="year",values="passengers")

# %%
fig, ax=plt.subplots(figsize=(12,8))
sns.heatmap(fc,annot=True, cmap="rainbow", fmt="d", linewidths=.5)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.countplot(data=tips, x="sex")
sns.set_style("darkgrid")
sns.set_context("poster, font_scale=0.5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 3
#       1 sns.countplot(data=tips, x="sex")
#       2 sns.set_style("darkgrid")
# ----> 3 sns.set_context("poster, font_scale=0.5")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\rcmod.py:469, in set_context(context, font_scale, rc)
#     436 def set_context(context=None, font_scale=1, rc=None):
#     437     """
#     438     Set the parameters that control the scaling of plot elements.
#     439
#    (...)
#     467
#     468     """
# --> 469     context_object = plotting_context(context, font_scale, rc)
#     470     mpl.rcParams.update(context_object)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\rcmod.py:380, in plotting_context(context, font_scale, rc)
#     378 contexts = ["paper", "notebook", "talk", "poster"]
#     379 if context not in contexts:
# ...

# %%
#distribution plot

sns.displot(tips["total_bill"],kde=True, bins= 30)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#joint plot
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg")
#kind="hex"
#kind="kde"

# %%
#Pairplot

sns.pairplot(tips, hue ="sex")
#palette="coolwarm"
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Categorical plot

# %%
#barplot
sns.barplot(data= tips, x="sex",y="total_bill", estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(data= tips, x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
##Boxplot
sns.boxplot(x="day", y="total_bill", data=tips, palette="rainbow", hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#violin plot

sns.violinplot(x="day", y="total_bill",data=tips, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill",data=tips,jitter=True, palette="Set1", hue= "smoker")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style ('white')

# %%
sns.swarmplot(x="day", y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill",data=tips, palette="rainbow")
sns.swarmplot(x="day", y="total_bill",data=tips, color="black")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
##factorplot=catplot
sns.catplot(x="day", y="total_bill",data=tips, kind ="bar")
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Regression plot

# %%
sns.lmplot(x="total_bill",y="tip",data=tips, hue="sex", scatter_kws={"s":100},markers=["o","v"])
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(x="total_bill", y="tip", data=tips,hue ="sex", col="day")
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
